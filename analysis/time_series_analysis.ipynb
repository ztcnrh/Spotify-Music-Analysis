# %%
# Dependecies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib import rcParams
import matplotlib.animation as animation

# %% [markdown]
# ## Using MatplotLib to Chart a DataFrame

# %%
# Loading the data
file = '../cleaned_data/cleaned_data_by_year.csv'
year_df = pd.read_csv(file)
year_df.head()
# Out:
#    year  acousticness  danceability    duration_ms    energy  \
# 0  1920      0.631242      0.515750  238092.997135  0.418700
# 1  1921      0.862105      0.432171  257891.762821  0.241136
# 2  1922      0.828934      0.575620  140135.140496  0.226173
# 3  1923      0.957247      0.577341  177942.362162  0.262406
# 4  1924      0.940200      0.549894  191046.707627  0.344347
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.354219  0.216049 -12.654020     0.082984  113.226900  0.498210
# 1          0.337158  0.205219 -16.811660     0.078952  102.425397  0.378276
# 2          0.254776  0.256662 -20.840083     0.464368  100.033149  0.571190
# 3          0.371733  0.227462 -14.129211     0.093949  114.010730  0.625492
# 4          0.581701  0.235219 -14.231343     0.092089  120.689572  0.663725
#
#    popularity  key  mode
# 0    0.610315    2     1
# 1    0.391026    2     1
# 2    0.090909    5     1
# 3    5.205405    0     1
# ...

# %%
# Parse out common ranges inot it's own DataFrame
line_data = year_df[['year','acousticness','danceability','energy','instrumentalness','liveness','speechiness','valence']]
line_data

# label='Loudness') # Out of sync
# label='Tempo') # Out of sync
# label='Popularity') # Out of sync
# Out:
#      year  acousticness  danceability    energy  instrumentalness  liveness  \
# 0    1920      0.631242      0.515750  0.418700          0.354219  0.216049
# 1    1921      0.862105      0.432171  0.241136          0.337158  0.205219
# 2    1922      0.828934      0.575620  0.226173          0.254776  0.256662
# 3    1923      0.957247      0.577341  0.262406          0.371733  0.227462
# 4    1924      0.940200      0.549894  0.344347          0.581701  0.235219
# ..    ...           ...           ...       ...               ...       ...
# 97   2017      0.207413      0.580475  0.686392          0.247068  0.231513
# 98   2018      0.233836      0.602731  0.659552          0.229874  0.231009
# 99   2019      0.261344      0.603101  0.629781          0.221123  0.218501
# 100  2020      0.202303      0.605285  0.674247          0.249008  0.234415
# 101  2021      0.340253      0.652488  0.578896          0.356765  0.162309
#
#      speechiness   valence
# 0       0.082984  0.498210
# ...

# %%
# Data
plt.plot(line_data['year'], line_data.iloc[:,1], label='Acousticness')
plt.plot(line_data['year'], line_data.iloc[:,2], label='Danceability')
plt.plot(line_data['year'], line_data.iloc[:,3], label='Energy')
plt.plot(line_data['year'], line_data.iloc[:,4], label='Instrumentalness')
plt.plot(line_data['year'], line_data.iloc[:,5], label='Speechiness')
plt.plot(line_data['year'], line_data.iloc[:,6], label='Valence')

plt.rcParams['axes.facecolor'] = '#F5F5F5'
plt.grid(True, color='k', linestyle=':')
plt.title("Common Music Charateristics vs. Year")
plt.xlabel("By Year")
plt.ylabel("By Charateristics Rating")
plt.legend(bbox_to_anchor=(1, 1))
# plt.figure(figsize=(12,8))
# plt.savefig('../common_music_test.png')

plt.show()


# plt.plot(year_df.acousticness)
# semicolon suppress the chart
# plt.legend(loc=8);
# plt.style.use('ggplot')
# plt.legend(loc=2);
# plt.figure(figsize=(100,50))
# plt.ylim(2500,2500)

# %%
plt.plot(line_data['year'], line_data.iloc[:,1], label='Acousticness')


plt.rcParams['axes.facecolor'] = '#F5F5F5'
plt.grid(True, color='k', linestyle=':')
plt.title("Acousticness vs. Year")
plt.xlabel("By Year")
plt.ylabel("By Charateristics Rating")
plt.legend(bbox_to_anchor=(1, 1))
plt.savefig('../common_music_year.png')
# plt.figure(figsize=(100,25000))

plt.show()

# %%
plt.plot(line_data['year'], line_data.iloc[:,2], label='Danceability', color='orange')


plt.rcParams['axes.facecolor'] = '#F5F5F5'
plt.grid(True, color='k', linestyle=':')
plt.title("Danceability vs. Year")
plt.xlabel("By Year")
plt.ylabel("By Charateristics Rating")
plt.legend(loc=4);
# # plt.figure(figsize=(100,25000))

plt.show()

# %%
plt.plot(line_data['year'], line_data.iloc[:,3], label='Energy', color='green')


plt.rcParams['axes.facecolor'] = '#F5F5F5'
plt.grid(True, color='k', linestyle=':')
plt.title("Energy vs. Year")
plt.xlabel("By Year")
plt.ylabel("By Charateristics Rating")
plt.legend(loc=2);
# plt.figure(figsize=(100,25000))

plt.show()

# %%
plt.plot(line_data['year'], line_data.iloc[:,4], label='Instrumentalness', color='red')


plt.rcParams['axes.facecolor'] = '#F5F5F5'
plt.grid(True, color='k', linestyle=':')
plt.title("Instrumentalnesss vs. Year")
plt.xlabel("By Year")
plt.ylabel("By Charateristics Rating")
plt.legend(bbox_to_anchor=(1, 1))
# plt.figure(figsize=(100,25000))

plt.show()

# %%
plt.plot(line_data['year'], line_data.iloc[:,5], label='Speechiness', color='purple')


plt.rcParams['axes.facecolor'] = '#F5F5F5'
plt.grid(True, color='k', linestyle=':')
plt.title("Speechiness vs. Year")
plt.xlabel("By Year")
plt.ylabel("By Charateristics Rating")
plt.legend(bbox_to_anchor=(1, 1))
# plt.figure(figsize=(100,25000))

plt.show()

# %%
plt.plot(line_data['year'], line_data.iloc[:,6], label='Valence', color='brown')

plt.rcParams['axes.facecolor'] = '#F5F5F5'
plt.grid(True, color='k', linestyle=':')
plt.title("Valence vs. Year")
plt.xlabel("By Year")
plt.ylabel("By Charateristics Rating")
plt.legend(bbox_to_anchor=(1, 1))
# plt.figure(figsize=(100,25000))

plt.show()

# %%
plt.plot(year_df['year'], year_df.iloc[:,6], label='Loudness', color='navy')

plt.rcParams['axes.facecolor'] = '#F5F5F5'
plt.grid(True, color='k', linestyle=':')
plt.title("Loudness vs. Year")
plt.xlabel("By Year")
plt.ylabel("By Charateristics Rating")
plt.legend(bbox_to_anchor=(1, 1))

plt.show()

# %%
plt.plot(year_df['year'], year_df.iloc[:,8], label='Tempo', color='m')

plt.rcParams['axes.facecolor'] = '#F5F5F5'
plt.grid(True, color='k', linestyle=':')
plt.title("Tempo vs. Year")
plt.xlabel("By Year")
plt.ylabel("By Charateristics Rating")
plt.legend(bbox_to_anchor=(1, 1))
# plt.figure(figsize=(100,25000))

plt.show()

# %%
plt.plot(year_df['year'], year_df.iloc[:,10], label='Popularity', color='teal')

plt.rcParams['axes.facecolor'] = '#F5F5F5'
plt.grid(True, color='k', linestyle=':')
plt.title("Popularity vs. Year")
plt.xlabel("By Year")
plt.ylabel("By Charateristics Rating")
plt.legend(bbox_to_anchor=(1, 1))

plt.show()
